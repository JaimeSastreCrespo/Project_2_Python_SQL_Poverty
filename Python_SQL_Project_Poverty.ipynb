# %% [markdown]
# <a href="https://colab.research.google.com/github/Borysdb/Project_2_Python_SQL_Poverty/blob/main/Python_SQL_Project_Poverty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install wbgapi #-> this is world bank data

import pandas as pd
import matplotlib.pyplot as plt
import wbgapi as wb # -> this is connection to world bank data

#help - some API's we can get more info about them
#help(wb)  <--- code to get data
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
wb.source.info() #categories
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2022-09-16
# 3     Worldwide Governance Indicators                                       WGI              3  2022-09-23
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2022-01-14
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2020-12-20
# ...

# %%
wb.economy.info() # countries with income levels
# Out:
# id    value                                                 region    incomeLevel
# ----  ----------------------------------------------------  --------  -------------
# ABW   Aruba                                                 LCN       HIC
# AFE   Africa Eastern and Southern
# AFG   Afghanistan                                           SAS       LIC
# AFW   Africa Western and Central
# AGO   Angola                                                SSF       LMC
# ALB   Albania                                               ECS       UMC
# AND   Andorra                                               ECS       HIC
# ARB   Arab World
# ARE   United Arab Emirates                                  MEA       HIC
# ARG   Argentina                                             LCN       UMC
# ARM   Armenia                                               ECS       UMC
# ASM   American Samoa                                        EAS       UMC
# ...

# %%
#wb.series.info()

# %%
wb.series.info(q="GDP per capita")
# Out:
# id                 value
# -----------------  ---------------------------------------------------
# NY.GDP.PCAP.CD     GDP per capita (current US$)
# NY.GDP.PCAP.CN     GDP per capita (current LCU)
# NY.GDP.PCAP.KD     GDP per capita (constant 2015 US$)
# NY.GDP.PCAP.KD.ZG  GDP per capita growth (annual %)
# NY.GDP.PCAP.KN     GDP per capita (constant LCU)
# NY.GDP.PCAP.PP.CD  GDP per capita, PPP (current international $)
# NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2017 international $)
#                    7 elements

# %%
wb.series.info(q="homici")
# Out:
# id                 value
# -----------------  --------------------------------------------------
# VC.IHR.PSRC.FE.P5  Intentional homicides, female (per 100,000 female)
# VC.IHR.PSRC.MA.P5  Intentional homicides, male (per 100,000 male)
# VC.IHR.PSRC.P5     Intentional homicides (per 100,000 people)
#                    3 elements

# %%
wb.series.info(q="Domestic general government health expenditure")
# Out:
# id                 value
# -----------------  ----------------------------------------------------------------------------------------
# SH.XPD.GHED.CH.ZS  Domestic general government health expenditure (% of current health expenditure)
# SH.XPD.GHED.GD.ZS  Domestic general government health expenditure (% of GDP)
# SH.XPD.GHED.GE.ZS  Domestic general government health expenditure (% of general government expenditure)
# SH.XPD.GHED.PC.CD  Domestic general government health expenditure per capita (current US$)
# SH.XPD.GHED.PP.CD  Domestic general government health expenditure per capita, PPP (current international $)
#                    5 elements

# %%
wb.series.info(q="corruption")
# Out:
# id              value
# --------------  -----------------------------------------------------------------------------------------------
# IQ.CPA.TRAN.XQ  CPIA transparency, accountability, and corruption in the public sector rating (1=low to 6=high)
#                 1 elements

# %%
wb.series.info(q="Unemployment, total (% of total labor force)")
# Out:
# id                 value
# -----------------  -------------------------------------------------------------------
# SL.UEM.TOTL.NE.ZS  Unemployment, total (% of total labor force) (national estimate)
# SL.UEM.TOTL.ZS     Unemployment, total (% of total labor force) (modeled ILO estimate)
#                    2 elements

# %%
wb.series.info(q="School enrollment, tertiary")
# Out:
# id                 value
# -----------------  --------------------------------------------------------------
# SE.ENR.TERT.FM.ZS  School enrollment, tertiary (gross), gender parity index (GPI)
# SE.TER.ENRR        School enrollment, tertiary (% gross)
# SE.TER.ENRR.FE     School enrollment, tertiary, female (% gross)
# SE.TER.ENRR.MA     School enrollment, tertiary, male (% gross)
#                    4 elements

# %%
#Charts Creation below

business = wb.data.DataFrame('IC.REG.DURS', wb.region.members('ECS'))
business

#filter data
ren = wb.data.DataFrame('IC.REG.DURS', ['FRA','UKR','EST'], time=range(2003,2019))
ren

#charts
ren.plot.bar()

wb.data.DataFrame('IC.REG.DURS', ['FRA','UKR','ENG'], time=range(2000,2019,3)).T.plot()

#another chart with selected countries
g5 = business.sort_values(by=['YR2019'],ascending=True)[:3]
ax = business.T.plot(color='lightgray', legend=False)
g5.T.plot(ax=ax, figsize=(15,5))

# %%
#Filtering info about = Start-up procedures to register a business (number)

wb.series.info(q="Start-up")
# Out:
# id                    value
# --------------------  ------------------------------------------------------------------
# IC.REG.COST.PC.FE.ZS  Cost of business start-up procedures, female (% of GNI per capita)
# IC.REG.COST.PC.MA.ZS  Cost of business start-up procedures, male (% of GNI per capita)
# IC.REG.COST.PC.ZS     Cost of business start-up procedures (% of GNI per capita)
# IC.REG.PROC           Start-up procedures to register a business (number)
# IC.REG.PROC.FE        Start-up procedures to register a business, female (number)
# IC.REG.PROC.MA        Start-up procedures to register a business, male (number)
#                       6 elements

# %%
ren = wb.data.DataFrame('IC.REG.PROC', ['GBR','FRA','POL','UKR'], time=range(2003,2019))
ren

#charts
ren.plot.bar()
wb.data.DataFrame('IC.REG.PROC', ['GBR','FRA','POL','UKR'], time=range(2000,2019,3)).T.plot()

business2 = wb.data.DataFrame('IC.REG.PROC', wb.region.members('ECS'))

g5 = business.sort_values(by=['YR2019'],ascending=True)[:20]
ax = business.T.plot(color='lightgray', legend=False)
g5.T.plot(ax=ax, figsize=(15,5))

# %%
g5 = business.sort_values(by=['YR2019'],ascending=True)[:3]
ax = business.T.plot(color='lightgray', legend=False)
g5.T.plot(ax=ax, figsize=(15,5))
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# ALB         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ARM         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AUT         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AZE         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BEL         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BGR         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BIH         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BLR         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# CHE         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# CHI         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# CYP         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...
